# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
covid_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Project/COVID-19 Cases(08-06-2022).csv')

# %%
covid_df
# Out:
#        S. No.        Date Region  Confirmed Cases  Active Cases  \
# 0           1  01/01/1970  India         34697860       91456.0
# 1           2  21/12/2014  India         34703644       88993.0
# 2           3  21/12/2015  India         34710628       87562.0
# 3           4  12/03/2020  India               74          71.0
# 4           5  13/03/2020  India               75          71.0
# ...       ...         ...    ...              ...           ...
# 29580   29581  02/06/2022  World        528275339           NaN
# 29581   29582  03/06/2022  World        528840437           NaN
# 29582   29583  04/06/2022  World        529100270           NaN
# 29583   29584  05/06/2022  World        529237449           NaN
# 29584   29585  06/06/2022  World        529410287           NaN
#
#        Cured/Discharged      Death
# 0            34130768.0   475636.0
# 1            34138763.0   475888.0
# 2            34146931.0   476135.0
# 3                   3.0        0.0
# ...

# %%
covid_df.head()
# Out:
#    S. No.        Date Region  Confirmed Cases  Active Cases  Cured/Discharged  \
# 0       1  01/01/1970  India         34697860       91456.0        34130768.0
# 1       2  21/12/2014  India         34703644       88993.0        34138763.0
# 2       3  21/12/2015  India         34710628       87562.0        34146931.0
# 3       4  12/03/2020  India               74          71.0               3.0
# 4       5  13/03/2020  India               75          71.0               3.0
#
#       Death
# 0  475636.0
# 1  475888.0
# 2  476135.0
# 3       0.0
# 4       1.0

# %%
covid_df.head(15)
# Out:
#     S. No.        Date Region  Confirmed Cases  Active Cases  \
# 0        1  01/01/1970  India         34697860       91456.0
# 1        2  21/12/2014  India         34703644       88993.0
# 2        3  21/12/2015  India         34710628       87562.0
# 3        4  12/03/2020  India               74          71.0
# 4        5  13/03/2020  India               75          71.0
# 5        6  14/03/2020  India               84          72.0
# 6        7  15/03/2020  India              107          95.0
# 7        8  16/03/2020  India              114          99.0
# 8        9  17/03/2020  India              137         120.0
# 9       10  18/03/2020  India              146         129.0
# 10      11  19/03/2020  India              166         148.0
# 11      12  20/03/2020  India              195         171.0
# 12      13  21/03/2020  India              258         231.0
# 13      14  22/03/2020  India              360         329.0
# ...

# %%
covid_df.tail(10)
# Out:
#        S. No.        Date Region  Confirmed Cases  Active Cases  \
# 29575   29576  28/05/2022  World        526017732           NaN
# 29576   29577  29/05/2022  World        526560356           NaN
# 29577   29578  30/05/2022  World        526182662           NaN
# 29578   29579  31/05/2022  World        527166771           NaN
# 29579   29580  01/06/2022  World        527642168           NaN
# 29580   29581  02/06/2022  World        528275339           NaN
# 29581   29582  03/06/2022  World        528840437           NaN
# 29582   29583  04/06/2022  World        529100270           NaN
# 29583   29584  05/06/2022  World        529237449           NaN
# 29584   29585  06/06/2022  World        529410287           NaN
#
#        Cured/Discharged      Death
# 29575               NaN  6287974.0
# 29576               NaN  6289442.0
# 29577               NaN  6286057.0
# 29578               NaN  6291010.0
# 29579               NaN  6291977.0
# 29580               NaN  6293414.0
# ...

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29585 entries, 0 to 29584
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   S. No.            29585 non-null  int64
#  1   Date              29585 non-null  object
#  2   Region            29585 non-null  object
#  3   Confirmed Cases   29585 non-null  int64
#  4   Active Cases      28763 non-null  float64
#  5   Cured/Discharged  28762 non-null  float64
#  6   Death             29584 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 1.6+ MB

# %%
covid_df.describe()
# Out:
#              S. No.  Confirmed Cases  Active Cases  Cured/Discharged  \
# count  29585.000000     2.958500e+04  2.876300e+04      2.876200e+04
# mean   14793.000000     6.021637e+06  2.879583e+04      1.076526e+06
# std     8540.598193     3.936691e+07  1.542613e+05      4.192679e+06
# min        1.000000     0.000000e+00 -4.650820e+05      0.000000e+00
# 25%     7397.000000     1.219800e+04  1.670000e+02      1.065300e+04
# 50%    14793.000000     1.404920e+05  1.436000e+03      1.208030e+05
# 75%    22189.000000     7.926470e+05  9.752000e+03      7.163700e+05
# max    29585.000000     5.294103e+08  3.745237e+06      4.263336e+07
#
#               Death
# count  2.958400e+04
# mean   1.013407e+05
# std    6.248688e+05
# min    0.000000e+00
# 25%    1.300000e+02
# 50%    1.715500e+03
# 75%    9.661000e+03
# max    6.296771e+06

# %%
covid_df.columns
# Out:
# Index(['S. No.', 'Date', 'Region', 'Confirmed Cases', 'Active Cases',
#        'Cured/Discharged', 'Death'],
#       dtype='object')

# %%
covid_df.shape
# Out:
# (29585, 7)

# %%
covid_df['Confirmed Cases']
# Out:
# 0         34697860
# 1         34703644
# 2         34710628
# 3               74
# 4               75
#            ...
# 29580    528275339
# 29581    528840437
# 29582    529100270
# 29583    529237449
# 29584    529410287
# Name: Confirmed Cases, Length: 29585, dtype: int64

# %%
type(covid_df['Confirmed Cases'])
# Out:
# pandas.core.series.Series

# %%
covid_df['Confirmed Cases'][500]
# Out:
# 31812114

# %%
covid_df['Death'][500]
# Out:
# 426290.0

# %%
covid_df.count()
# Out:
# S. No.              29585
# Date                29585
# Region              29585
# Confirmed Cases     29585
# Active Cases        28763
# Cured/Discharged    28762
# Death               29584
# dtype: int64

# %%
covid_df.isnull()
# Out:
#        S. No.   Date  Region  Confirmed Cases  Active Cases  Cured/Discharged  \
# 0       False  False   False            False         False             False
# 1       False  False   False            False         False             False
# 2       False  False   False            False         False             False
# 3       False  False   False            False         False             False
# 4       False  False   False            False         False             False
# ...       ...    ...     ...              ...           ...               ...
# 29580   False  False   False            False          True              True
# 29581   False  False   False            False          True              True
# 29582   False  False   False            False          True              True
# 29583   False  False   False            False          True              True
# 29584   False  False   False            False          True              True
#
#        Death
# 0      False
# ...

# %%
covid_df.isnull().sum()
# Out:
# S. No.                0
# Date                  0
# Region                0
# Confirmed Cases       0
# Active Cases        822
# Cured/Discharged    823
# Death                 1
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(covid_df.isnull())
plt.show()

# %%
covid_df.head(2)
# Out:
#    S. No.        Date Region  Confirmed Cases  Active Cases  Cured/Discharged  \
# 0       1  01/01/1970  India         34697860       91456.0        34130768.0
# 1       2  21/12/2014  India         34703644       88993.0        34138763.0
#
#       Death
# 0  475636.0
# 1  475888.0

# %%
covid_df.groupby('Region').sum().head()
# Out:
#                               S. No.  Confirmed Cases  Active Cases  \
# Region
# Andaman and Nicobar Islands   915292          4362929       78060.0
# Andhra Pradesh               1552733        996962420    21994566.0
# Arunachal Pradesh            2109367         23709677      663143.0
# Assam                        2704625        284503975     7842712.0
# Bihar                        3348928        349656623     6559352.0
#
#                              Cured/Discharged      Death
# Region
# Andaman and Nicobar Islands         4221965.0    62904.0
# Andhra Pradesh                    968012515.0  6955339.0
# Arunachal Pradesh                  22939799.0   106735.0
# Assam                             274209900.0  2451363.0
# Bihar                             338821471.0  4275800.0

# %% [markdown]
# ## If i want to see only confirmed caes in region then i used this syntex

# %%
covid_df.groupby('Region')['Confirmed Cases'].sum().head(5)
# Out:
# Region
# Andaman and Nicobar Islands      4362929
# Andhra Pradesh                 996962420
# Arunachal Pradesh               23709677
# Assam                          284503975
# Bihar                          349656623
# Name: Confirmed Cases, dtype: int64

# %%
covid_df.groupby('Region')['Confirmed Cases'].sum().sort_values(ascending = False).head()
# Out:
# Region
# World          145940866678
# India           16104630909
# Maharashtra      3133056073
# Kerala           2023702751
# Karnataka        1443596603
# Name: Confirmed Cases, dtype: int64

# %%
covid_df.groupby('Region')['Confirmed Cases','Death'].sum().head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                              Confirmed Cases      Death
# Region
# Andaman and Nicobar Islands          4362929    62904.0
# Andhra Pradesh                     996962420  6955339.0
# Arunachal Pradesh                   23709677   106735.0
# Assam                              284503975  2451363.0
# Bihar                              349656623  4275800.0

# %%
covid_df[covid_df.Death<100]
# Out:
#        S. No.        Date       Region  Confirmed Cases  Active Cases  \
# 3           4  12/03/2020        India               74          71.0
# 4           5  13/03/2020        India               75          71.0
# 5           6  14/03/2020        India               84          72.0
# 6           7  15/03/2020        India              107          95.0
# 7           8  16/03/2020        India              114          99.0
# ...       ...         ...          ...              ...           ...
# 28024   28025  30/04/2020  West Bengal              758         612.0
# 28025   28026  01/05/2020  West Bengal              795         623.0
# 28026   28027  02/05/2020  West Bengal              795         623.0
# 28027   28028  03/05/2020  West Bengal              922         738.0
# 28028   28029  04/05/2020  West Bengal              963         777.0
#
#        Cured/Discharged  Death
# 3                   3.0    0.0
# 4                   3.0    1.0
# ...

# %% [markdown]
# **IN WHICH REGION, MAXIMUM NO OF CONFIRMED CASES WERE RECORTED?**

# %%
covid_df.head(5)
# Out:
#    S. No.        Date Region  Confirmed Cases  Active Cases  Cured/Discharged  \
# 0       1  01/01/1970  India         34697860       91456.0        34130768.0
# 1       2  21/12/2014  India         34703644       88993.0        34138763.0
# 2       3  21/12/2015  India         34710628       87562.0        34146931.0
# 3       4  12/03/2020  India               74          71.0               3.0
# 4       5  13/03/2020  India               75          71.0               3.0
#
#       Death
# 0  475636.0
# 1  475888.0
# 2  476135.0
# 3       0.0
# 4       1.0

# %%
covid_df.groupby('Region')['Confirmed Cases'].sum().sort_values(ascending = False).head(20)
# Out:
# Region
# World             145940866678
# India              16104630909
# Maharashtra         3133056073
# Kerala              2023702751
# Karnataka           1443596603
# Tamil Nadu          1280397856
# Andhra Pradesh       996962420
# Uttar Pradesh        835366930
# West Bengal          765199936
# Delhi                745372483
# Odisha               481565596
# Rajasthan            469785456
# Chhattisgarh         463021752
# Gujarat              424845521
# Madhya Pradesh       388070102
# Haryana              377105664
# Bihar                349656623
# Telangana            332178317
# Punjab               288386232
# Assam                284503975
# Name: Confirmed Cases, dtype: int64

# %% [markdown]
# **IN WHICH REGION MINIMUM NO. OF DEATHS WERE RECORTED**?

# %%
covid_df.groupby('Region')['Death'].sum().sort_values(ascending = True).head(20)
# Out:
# Region
# State assignment pending                          0.0
# Dadra and Nagar Haveli and Daman and Diu       2130.0
# Lakshadweep                                   18394.0
# Andaman and Nicobar Islands                   62904.0
# Ladakh                                       106321.0
# Arunachal Pradesh                            106735.0
# Mizoram                                      158433.0
# Sikkim                                       169813.0
# Nagaland                                     258185.0
# Tripura                                      390428.0
# Chandigarh                                   430597.0
# Meghalaya                                    523172.0
# Manipur                                      734935.0
# Puducherry                                   841738.0
# Goa                                         1442235.0
# Himachal Pradesh                            1588866.0
# Telangana                                   1869932.0
# ...

# %% [markdown]
# **CHANGE COLUMN NAME 'CURED/DISCHARGE' TO 'CURED CASES'**

# %%
covid_df.rename(columns={'Cured/Discharged':'Cure Case'} ,inplace=True)

# %%
covid_df.head(2)
# Out:
#    S. No.        Date Region  Confirmed Cases  Active Cases   Cure Case  \
# 0       1  01/01/1970  India         34697860       91456.0  34130768.0
# 1       2  21/12/2014  India         34703644       88993.0  34138763.0
#
#       Death
# 0  475636.0
# 1  475888.0

# %% [markdown]
# **HOW MANY CONFIRMED,DEATHS,CURE CASES CASES WERE RECORTED IN PERTICULAR REGION**?

# %%
covid_df[covid_df.Region == 'Goa'].head()
# Out:
#       S. No.        Date Region  Confirmed Cases  Active Cases  Cure Case  \
# 7769    7770  01/01/1970    Goa           179454         411.0   175561.0
# 7770    7771  21/12/2014    Goa           179469         382.0   175605.0
# 7771    7772  21/12/2015    Goa           179513         390.0   175641.0
# 7772    7773  26/03/2020    Goa                3           3.0        0.0
# 7773    7774  27/03/2020    Goa                3           3.0        0.0
#
#        Death
# 7769  3482.0
# 7770  3482.0
# 7771  3482.0
# 7772     0.0
# 7773     0.0

# %% [markdown]
# **SORT ENTIRE DATA W.R.T DEATH IN Adescending ORDER in india**

# %%
covid_df.sort_values(by=['Death'],ascending=False)[covid_df.Region == 'India'].head(50)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      S. No.        Date Region  Confirmed Cases  Active Cases   Cure Case  \
# 790     791  07/06/2022  India         43185049       26976.0  42633365.0
# 789     790  06/06/2022  India         43181335       25776.0  42630852.0
# 788     789  05/06/2022  India         43176817       24052.0  42628073.0
# 787     788  04/06/2022  India         43172547       22403.0  42625454.0
# 786     787  03/06/2022  India         43168585       21177.0  42622757.0
# 785     786  02/06/2022  India         43164544       19509.0  42620394.0
# 784     785  01/06/2022  India         43160832       18381.0  42617810.0
# 783     784  31/05/2022  India         43158087       17883.0  42615574.0
# 782     783  30/05/2022  India         43155749       17681.0  42613440.0
# ...
